# %% [markdown]
# # Final Assignment - Big Data Programming
# ### Written and Coded by Connor Parnham

# %% [markdown]
# #### Lets Import our Libraries we will use

# %%
import pandas as pd
import numpy as np
import sklearn as sk
import datetime
import re
import seaborn as sns
from sklearn.metrics import confusion_matrix, mean_squared_error, r2_score
from sklearn.preprocessing import StandardScaler, LabelEncoder, scale, PolynomialFeatures
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.feature_selection import RFE
import statsmodels.api as sm
from sklearn.tree import export_graphviz
# !conda install --yes pydot
# Out:
# Collecting package metadata (current_repodata.json): ...working... done
# Solving environment: ...working... done
#
# # All requested packages already installed.

# %% [markdown]
# #### Import our Dataset (From Kaggle)

# %%
#Load in the data set and see how the data is structured
df = pd.read_csv(r'PGA_Data_Historical.csv')
df2 = df.set_index(['Player Name', 'Variable','Season'])['Value'].unstack('Variable')
df2 = df2.reset_index()
#df['Season'] = pd.DatetimeIndex(df['Date']).year
#df.drop(['Date'], axis = 1)

# %% [markdown]
# #### After Looking at the excel sheet, I reduced the number of variables by taking only AVERAGES

# %%
# I want to under stand what data lies in each variable and its usefulness
# Will require alot of data cleaning
var = df['Variable'].unique()
df_var = pd.DataFrame(var)
df_var.rename(columns={0:'Variable'})
#df_var.to_excel(r'C:\Users\foxnetadmin\Desktop\variables.xlsx')
var_final = pd.read_excel(r'variables.xlsx')
var_final = var_final.rename(columns={0:'Variable'})
var_final = var_final['Variable']
var_list = var_final.values.tolist()
dataset = df2[df2.columns.intersection(var_list)]
dataset = dataset.rename(columns = {'Total Money (Official and Unofficial) - (MONEY)': 'Money'})
dataset = dataset[dataset['Money'].notna()] # if they aren't making money then there is no point of having them in the data set
dataset = dataset[dataset['Birdie Average - (AVG)'].notna()] # Took the most measured variable in golf. If a player does hold this variable then there is no point of having them in data set.
data = pd.read_excel(r'dataset.xlsx')

# %% [markdown]
# ### Had to Seperate the Data to fix Data Types

# %%
# Had to do some data manipulation as not all data was numeric and there for needed to converted
player = data['Player Name']
int_data = data.select_dtypes(include=['int64'])
float_data = data.select_dtypes(include=['float64'])
obj_data = data.select_dtypes(include=['object'])
obj_data = obj_data.drop(['Player Name'], axis=1)
obj_data = obj_data.astype(str)
regex_o = re.compile(r'.\d$', flags=re.IGNORECASE) # regex to remove the decimals from the data. to Convert it to numeric
obj_data = obj_data.replace(regex_o,'')
obj_data = obj_data.apply(pd.to_numeric)

# Combine the data points together
data = pd.concat([player, int_data, obj_data, float_data], axis=1, sort=False)
data = data.drop(columns=['Unnamed: 0'])
corr = data.corr()
corr
# Out:
#                                                 Money  Apex Height - (AVG.)  \
# Money                                        1.000000              0.248973
# Apex Height - (AVG.)                         0.248973              1.000000
# Approaches from 100-125 yards (Rgh) - (AVG)  0.012705              0.114596
# Approaches from 100-125 yards - (AVG)       -0.150153              0.067667
# Approaches from 125-150 yards (Rgh) - (AVG) -0.017028              0.106610
# ...                                               ...                   ...
# Scrambling > 30 yds (RTP Score) - (AVG RTP) -0.263069              0.138574
# Scrambling Fringe (RTP Score) - (AVG RTP)   -0.187847             -0.090574
# Scrambling Rough (RTP Score) - (AVG RTP)    -0.380183              0.036610
# Smash Factor - (AVG.)                        0.065435              0.188066
# Spin Rate - (AVG.)                          -0.045542             -0.123122
#
#                                              Approaches from 100-125 yards (Rgh) - (AVG)  \
# Money                                                                           0.012705
# Apex Height - (AVG.)                                                            0.114596
# Approaches from 100-125 yards (Rgh) - (AVG)                                     1.000000
# Approaches from 100-125 yards - (AVG)                                           0.093239
# Approaches from 125-150 yards (Rgh) - (AVG)                                     0.063557
# ...                                                                                  ...
# Scrambling > 30 yds (RTP Score) - (AVG RTP)                                    -0.008726
# Scrambling Fringe (RTP Score) - (AVG RTP)                                      -0.033333
# Scrambling Rough (RTP Score) - (AVG RTP)                                        0.036819
# Smash Factor - (AVG.)                                                           0.006497
# Spin Rate - (AVG.)                                                              0.028570
#
#                                              Approaches from 100-125 yards - (AVG)  \
# Money                                                                    -0.150153
# Apex Height - (AVG.)                                                      0.067667
# Approaches from 100-125 yards (Rgh) - (AVG)                               0.093239
# Approaches from 100-125 yards - (AVG)                                     1.000000
# Approaches from 125-150 yards (Rgh) - (AVG)                               0.116367
# ...                                                                            ...
# Scrambling > 30 yds (RTP Score) - (AVG RTP)                               0.127708
# Scrambling Fringe (RTP Score) - (AVG RTP)                                 0.039162
# Scrambling Rough (RTP Score) - (AVG RTP)                                  0.065539
# Smash Factor - (AVG.)                                                    -0.070901
# Spin Rate - (AVG.)                                                        0.081367
#
#                                              Approaches from 125-150 yards (Rgh) - (AVG)  \
# Money                                                                          -0.017028
# Apex Height - (AVG.)                                                            0.106610
# Approaches from 100-125 yards (Rgh) - (AVG)                                     0.063557
# Approaches from 100-125 yards - (AVG)                                           0.116367
# Approaches from 125-150 yards (Rgh) - (AVG)                                     1.000000
# ...                                                                                  ...
# Scrambling > 30 yds (RTP Score) - (AVG RTP)                                    -0.009061
# Scrambling Fringe (RTP Score) - (AVG RTP)                                       0.004180
# Scrambling Rough (RTP Score) - (AVG RTP)                                        0.037178
# Smash Factor - (AVG.)                                                           0.027774
# Spin Rate - (AVG.)                                                             -0.024872
#
#                                              Approaches from 125-150 yards - (AVG)  \
# Money                                                                    -0.215522
# Apex Height - (AVG.)                                                      0.052812
# Approaches from 100-125 yards (Rgh) - (AVG)                               0.059331
# Approaches from 100-125 yards - (AVG)                                     0.314242
# Approaches from 125-150 yards (Rgh) - (AVG)                               0.085273
# ...                                                                            ...
# Scrambling > 30 yds (RTP Score) - (AVG RTP)                               0.130482
# Scrambling Fringe (RTP Score) - (AVG RTP)                                 0.090425
# Scrambling Rough (RTP Score) - (AVG RTP)                                  0.150619
# Smash Factor - (AVG.)                                                    -0.059689
# Spin Rate - (AVG.)                                                        0.070410
#
#                                              Approaches from 150-175 yards (Rgh) - (AVG)  \
# Money                                                                          -0.033642
# Apex Height - (AVG.)                                                            0.051754
# Approaches from 100-125 yards (Rgh) - (AVG)                                     0.026149
# Approaches from 100-125 yards - (AVG)                                           0.054371
# Approaches from 125-150 yards (Rgh) - (AVG)                                     0.132480
# ...                                                                                  ...
# Scrambling > 30 yds (RTP Score) - (AVG RTP)                                    -0.000647
# Scrambling Fringe (RTP Score) - (AVG RTP)                                      -0.018370
# Scrambling Rough (RTP Score) - (AVG RTP)                                        0.066451
# Smash Factor - (AVG.)                                                           0.028176
# Spin Rate - (AVG.)                                                             -0.031535
#
#                                              Approaches from 150-175 yards - (AVG)  \
# Money                                                                    -0.281174
# Apex Height - (AVG.)                                                      0.035893
# Approaches from 100-125 yards (Rgh) - (AVG)                               0.117060
# Approaches from 100-125 yards - (AVG)                                     0.237561
# Approaches from 125-150 yards (Rgh) - (AVG)                               0.105394
# ...                                                                            ...
# Scrambling > 30 yds (RTP Score) - (AVG RTP)                               0.082327
# Scrambling Fringe (RTP Score) - (AVG RTP)                                 0.047046
# Scrambling Rough (RTP Score) - (AVG RTP)                                  0.130520
# Smash Factor - (AVG.)                                                    -0.023734
# Spin Rate - (AVG.)                                                        0.089480
#
#                                              Approaches from 175-200 yards (Rgh) - (AVG)  \
# Money                                                                          -0.121350
# Apex Height - (AVG.)                                                           -0.001911
# Approaches from 100-125 yards (Rgh) - (AVG)                                     0.058443
# Approaches from 100-125 yards - (AVG)                                           0.020326
# Approaches from 125-150 yards (Rgh) - (AVG)                                     0.014528
# ...                                                                                  ...
# Scrambling > 30 yds (RTP Score) - (AVG RTP)                                    -0.002730
# Scrambling Fringe (RTP Score) - (AVG RTP)                                      -0.000916
# Scrambling Rough (RTP Score) - (AVG RTP)                                        0.091620
# Smash Factor - (AVG.)                                                          -0.001163
# Spin Rate - (AVG.)                                                             -0.034387
#
#                                              Approaches from 175-200 yards - (AVG)  \
# Money                                                                    -0.063219
# Apex Height - (AVG.)                                                     -0.077264
# Approaches from 100-125 yards (Rgh) - (AVG)                               0.013134
# Approaches from 100-125 yards - (AVG)                                     0.017318
# Approaches from 125-150 yards (Rgh) - (AVG)                               0.022973
# ...                                                                            ...
# Scrambling > 30 yds (RTP Score) - (AVG RTP)                               0.035202
# Scrambling Fringe (RTP Score) - (AVG RTP)                                 0.003815
# Scrambling Rough (RTP Score) - (AVG RTP)                                  0.058218
# Smash Factor - (AVG.)                                                    -0.139323
# Spin Rate - (AVG.)                                                        0.160863
#
#                                              ...  \
# Money                                        ...
# Apex Height - (AVG.)                         ...
# Approaches from 100-125 yards (Rgh) - (AVG)  ...
# Approaches from 100-125 yards - (AVG)        ...
# Approaches from 125-150 yards (Rgh) - (AVG)  ...
# ...                                          ...
# Scrambling > 30 yds (RTP Score) - (AVG RTP)  ...
# Scrambling Fringe (RTP Score) - (AVG RTP)    ...
# Scrambling Rough (RTP Score) - (AVG RTP)     ...
# Smash Factor - (AVG.)                        ...
# Spin Rate - (AVG.)                           ...
#
#                                              Scoring Average (Actual) - (AVG)  \
# Money                                                               -0.625683
# Apex Height - (AVG.)                                                -0.135894
# Approaches from 100-125 yards (Rgh) - (AVG)                          0.021830
# Approaches from 100-125 yards - (AVG)                                0.214891
# Approaches from 125-150 yards (Rgh) - (AVG)                          0.059672
# ...                                                                       ...
# Scrambling > 30 yds (RTP Score) - (AVG RTP)                          0.388068
# Scrambling Fringe (RTP Score) - (AVG RTP)                            0.213586
# Scrambling Rough (RTP Score) - (AVG RTP)                             0.492961
# Smash Factor - (AVG.)                                               -0.076072
# Spin Rate - (AVG.)                                                   0.000901
#
#                                              Scoring Average - (AVG)  \
# Money                                                      -0.747803
# Apex Height - (AVG.)                                       -0.159188
# Approaches from 100-125 yards (Rgh) - (AVG)                 0.010511
# Approaches from 100-125 yards - (AVG)                       0.187863
# Approaches from 125-150 yards (Rgh) - (AVG)                 0.070181
# ...                                                              ...
# Scrambling > 30 yds (RTP Score) - (AVG RTP)                 0.402943
# Scrambling Fringe (RTP Score) - (AVG RTP)                   0.201711
# Scrambling Rough (RTP Score) - (AVG RTP)                    0.503916
# Smash Factor - (AVG.)                                      -0.057557
# Spin Rate - (AVG.)                                         -0.015908
#
#                                              Scrambling - (%)  \
# Money                                                0.315002
# Apex Height - (AVG.)                                -0.085452
# Approaches from 100-125 yards (Rgh) - (AVG)         -0.020731
# Approaches from 100-125 yards - (AVG)               -0.122692
# Approaches from 125-150 yards (Rgh) - (AVG)         -0.047299
# ...                                                       ...
# Scrambling > 30 yds (RTP Score) - (AVG RTP)         -0.481071
# Scrambling Fringe (RTP Score) - (AVG RTP)           -0.244725
# Scrambling Rough (RTP Score) - (AVG RTP)            -0.672425
# Smash Factor - (AVG.)                                0.033298
# Spin Rate - (AVG.)                                  -0.012480
#
#                                              Scrambling 10-20 yds (RTP Score) - (AVG RTP)  \
# Money                                                                           -0.227844
# Apex Height - (AVG.)                                                             0.076552
# Approaches from 100-125 yards (Rgh) - (AVG)                                      0.018248
# Approaches from 100-125 yards - (AVG)                                            0.046511
# Approaches from 125-150 yards (Rgh) - (AVG)                                      0.029581
# ...                                                                                   ...
# Scrambling > 30 yds (RTP Score) - (AVG RTP)                                      0.248793
# Scrambling Fringe (RTP Score) - (AVG RTP)                                        0.180936
# Scrambling Rough (RTP Score) - (AVG RTP)                                         0.495077
# Smash Factor - (AVG.)                                                           -0.030868
# Spin Rate - (AVG.)                                                               0.010764
#
#                                              Scrambling 20-30 yds (RTP Score) - (AVG RTP)  \
# Money                                                                           -0.171409
# Apex Height - (AVG.)                                                             0.081088
# Approaches from 100-125 yards (Rgh) - (AVG)                                      0.036926
# Approaches from 100-125 yards - (AVG)                                            0.076877
# Approaches from 125-150 yards (Rgh) - (AVG)                                     -0.000970
# ...                                                                                   ...
# Scrambling > 30 yds (RTP Score) - (AVG RTP)                                      0.226836
# Scrambling Fringe (RTP Score) - (AVG RTP)                                        0.123361
# Scrambling Rough (RTP Score) - (AVG RTP)                                         0.353118
# Smash Factor - (AVG.)                                                           -0.009175
# Spin Rate - (AVG.)                                                              -0.022325
#
#                                              Scrambling > 30 yds (RTP Score) - (AVG RTP)  \
# Money                                                                          -0.263069
# Apex Height - (AVG.)                                                            0.138574
# Approaches from 100-125 yards (Rgh) - (AVG)                                    -0.008726
# Approaches from 100-125 yards - (AVG)                                           0.127708
# Approaches from 125-150 yards (Rgh) - (AVG)                                    -0.009061
# ...                                                                                  ...
# Scrambling > 30 yds (RTP Score) - (AVG RTP)                                     1.000000
# Scrambling Fringe (RTP Score) - (AVG RTP)                                       0.118339
# Scrambling Rough (RTP Score) - (AVG RTP)                                        0.479731
# Smash Factor - (AVG.)                                                          -0.042194
# Spin Rate - (AVG.)                                                             -0.026258
#
#                                              Scrambling Fringe (RTP Score) - (AVG RTP)  \
# Money                                                                        -0.187847
# Apex Height - (AVG.)                                                         -0.090574
# Approaches from 100-125 yards (Rgh) - (AVG)                                  -0.033333
# Approaches from 100-125 yards - (AVG)                                         0.039162
# Approaches from 125-150 yards (Rgh) - (AVG)                                   0.004180
# ...                                                                                ...
# Scrambling > 30 yds (RTP Score) - (AVG RTP)                                   0.118339
# Scrambling Fringe (RTP Score) - (AVG RTP)                                     1.000000
# Scrambling Rough (RTP Score) - (AVG RTP)                                      0.135505
# Smash Factor - (AVG.)                                                        -0.056811
# Spin Rate - (AVG.)                                                            0.005352
#
#                                              Scrambling Rough (RTP Score) - (AVG RTP)  \
# Money                                                                       -0.380183
# Apex Height - (AVG.)                                                         0.036610
# Approaches from 100-125 yards (Rgh) - (AVG)                                  0.036819
# Approaches from 100-125 yards - (AVG)                                        0.065539
# Approaches from 125-150 yards (Rgh) - (AVG)                                  0.037178
# ...                                                                               ...
# Scrambling > 30 yds (RTP Score) - (AVG RTP)                                  0.479731
# Scrambling Fringe (RTP Score) - (AVG RTP)                                    0.135505
# Scrambling Rough (RTP Score) - (AVG RTP)                                     1.000000
# Smash Factor - (AVG.)                                                       -0.060491
# Spin Rate - (AVG.)                                                           0.001250
#
#                                              Smash Factor - (AVG.)  \
# Money                                                     0.065435
# Apex Height - (AVG.)                                      0.188066
# Approaches from 100-125 yards (Rgh) - (AVG)               0.006497
# Approaches from 100-125 yards - (AVG)                    -0.070901
# Approaches from 125-150 yards (Rgh) - (AVG)               0.027774
# ...                                                            ...
# Scrambling > 30 yds (RTP Score) - (AVG RTP)              -0.042194
# Scrambling Fringe (RTP Score) - (AVG RTP)                -0.056811
# Scrambling Rough (RTP Score) - (AVG RTP)                 -0.060491
# Smash Factor - (AVG.)                                     1.000000
# Spin Rate - (AVG.)                                       -0.380431
#
#                                              Spin Rate - (AVG.)
# Money                                                 -0.045542
# Apex Height - (AVG.)                                  -0.123122
# Approaches from 100-125 yards (Rgh) - (AVG)            0.028570
# Approaches from 100-125 yards - (AVG)                  0.081367
# Approaches from 125-150 yards (Rgh) - (AVG)           -0.024872
# ...                                                         ...
# Scrambling > 30 yds (RTP Score) - (AVG RTP)           -0.026258
# Scrambling Fringe (RTP Score) - (AVG RTP)              0.005352
# Scrambling Rough (RTP Score) - (AVG RTP)               0.001250
# Smash Factor - (AVG.)                                 -0.380431
# Spin Rate - (AVG.)                                     1.000000
#
# [240 rows x 240 columns]

# %% [markdown]
# #### Dimensionality Reduction through Correlation Analysis to the target
# ##### We now have gone from 2000 variables to 110

# %%
#data.to_csv(r'C:\Users\foxnetadmin\Documents\Winter Semester - BDSA\PROG8420 - Programming for Big Data\Assignments\Final Assignment\data.csv')
# after more work in excel, narrowed the variable list down to 52 using R

# %% [markdown]
# ## Model Development

# %%
# Ran Stepwise Selection in R to find the best model to predict 'Money'
# We now need to construct the data around the chosen variables
model_var = ["Approaches from 125-150 yards - (AVG)", "Approaches from 150-175 yards - (AVG)", "Approaches from 200-225 yards - (AVG)", "Approaches from 50-125 yards - (AVG)", "Approaches from > 100 yards - (AVG)",
"Approaches from > 200 yards - (AVG)", "3-Putt Avoidance - (%)", "Approach 125-150 yards (RTP Score) - (AVG RTP)", "Approach 150-175 yards (RTP Score) - (AVG RTP)", "Approach 175-200 yards (RTP Score) - (AVG RTP)",
"Approach 200-225 yards (RTP) - (AVG RTP)", "Approach < 125 yards (RTP Score) - (AVG RTP)", "Approach > 200 yards (RTP Score) - (AVG RTP)", "Approaches > 200 yards-Rgh (RTP) - (AVG RTP)", "Average Approach Shot Distance - (AVG)",
"Average Distance to Hole After Tee Shot - (AVG)", "Ball Speed - (AVG.)", "Birdie Average - (AVG)", "Birdie or Better Conversion Percentage - (%)", "Birdie or Better Percentage - (%)", "Bounce Back - (%)",
"Driving Pct. 240-260 (Measured) - (%)", "Driving Pct. 320+ (Measured) - (%)", "Early Par 3 Scoring Average - (AVG)", "Early Par 5 Scoring Average - (AVG)", "Fairway Approach (RTP Score) - (AVG RTP)",
"Final Round Performance - (%)", "First Tee Early Par 4 Scoring Average - (AVG)", "First Tee Early Par 5 Scoring Average - (AVG)", "First Tee Early Scoring Average - (AVG)", "First Tee Late Par 4 Scoring Average - (AVG)",
"GIR Percentage - 100+ yards - (%)", "GIR Percentage - 175-200 yards - (%)", "GIR Percentage - 200+ yards - (%)", "Going for the Green - (%)", "Good Drive Percentage - (%)", "Greens or Fringe in Regulation - (%)",
"Late Par 3 Scoring Average - (AVG)", "Late Par 5 Scoring Average - (AVG)", "One-Putt Percentage - (%)", "Par 4 Performance - (PAR 4 AVG)", "Par 5 Performance - (PAR 5 AVG)",
"Percentage of Yardage covered by Tee Shots - (AVG (%))", "Percentage of Yardage covered by Tee Shots - Par 4's - (AVG)", "Percentage of Yardage covered by Tee Shots - Par 5's - (AVG)", "Putting - Inside 10' - (% MADE)",
"Putts Per Round - (AVG)", "Scoring Average (Actual) - (AVG)", "Scoring Average - (AVG)", "Scrambling - (%)", "Scrambling > 30 yds (RTP Score) - (AVG RTP)", "Scrambling Rough (RTP Score) - (AVG RTP)", "Money"]
data1 = data[data.columns.intersection(model_var)]
data1 = data1[data1['Money'] >= 400000]

# %%
# Train and Test Split (90-10 Rule)
poly = PolynomialFeatures(2)
X = data1.drop('Money', axis = 1)
y = data1['Money']/1000000
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1, random_state=0)
lm = LinearRegression()
fit = lm.fit(X_train, y_train) # training the algorithm
print(lm.intercept_)
print(lm.coef_)

# Predictions
golf_y_pred = lm.predict(X_test)
actual_pred = pd.DataFrame({'Actual': y_test, 'Predicted': golf_y_pred})
r2 = r2_score(golf_y_pred, y_test)
print("\nR-Squared of the linear model:", round(r2,2))
actual_pred
# Out:
# -68.76843480875367
# [-4.86145164e-02 -4.52802118e-02 -7.87967346e-03 -4.58816075e-02
#   7.44394070e-02 -3.48746375e-02 -1.95925214e-01  3.88520922e+00
#   4.73545014e+00  4.42014566e+00  8.06847032e-01  4.59276883e+00
#   5.03081676e+00 -1.61608878e-01  6.68298776e-02  9.62695294e-02
#  -3.86948823e-02 -2.60669772e+00 -2.41925185e-01  1.09317254e+00
#  -3.14693343e-02  2.81199253e-02 -6.58112646e-03 -2.64588473e+00
#   6.72342915e+00 -2.80533228e+01  9.90763215e-03 -2.67061234e+00
#  -2.03715047e+00  4.98443708e-01 -3.05047150e+00 -3.67478073e-02
#   1.42036598e-02  2.05497052e-02 -2.75545856e-02 -1.77137220e-02
#  -7.75736784e-02 -1.40529041e+00  4.89801177e+00  1.28124310e-01
#  -6.29800582e+00 -1.30050623e+01  8.64411807e-01  6.93777816e-02
#   7.37106225e-01  1.77668808e+00 -1.64925253e+00  4.16861292e-02
#  -4.96870685e-01 -2.94317763e-01]
#
# R-Squared of the linear model: 0.63
#         Actual  Predicted
# 364   0.656672   0.354613
# 701   2.367521   1.244319
# 1371  0.468498  -0.100717
# 727   2.978181   4.852702
# 1464  2.002913   1.587496
# ...        ...        ...
# 1008  1.511275   1.779183
# 487   0.832640   1.318155
# 1171  1.935669   2.078359
# 1548  1.028960   0.992802
# 879   1.011430   1.659862
#
# [142 rows x 2 columns]

# %% [markdown]
# ### Random Forest Regressor (Decision Tree)
# #### Trying a different Technique

# %%
# Random Forest Regressor
rf = RandomForestRegressor(n_estimators = 1000, random_state=0)
rf.fit(X_train, y_train)

preds = rf.predict(X_test)
errors = abs(preds - y_test)
mean_error = round(np.mean(errors), 2)
mape = 100 * (errors / y_test)
accuracy = 100 - np.mean(mape)
accuracy
# Out:
# 60.06037121942111

# %%
import pydot
tree = rf.estimators_[5]
export_graphviz(tree, out_file = 'tree.dot', feature_names = X.columns, rounded = True, precision = 1)
(graph, ) = pydot.graph_from_dot_file('tree.dot')
graph.write_png('tree.png')

# %%
rf_small = RandomForestRegressor(n_estimators=10, max_depth = 5)
rf_small.fit(X_train, y_train)
tree_small = rf_small.estimators_[5]
export_graphviz(tree_small, out_file = 'small_tree.dot', feature_names = X.columns, rounded = True, precision = 1)
(graph, ) = pydot.graph_from_dot_file('small_tree.dot')
graph.write_png('small_tree.png');

# %%
#X_test.to_excel(r'C:\Users\foxnetadmin\Documents\Winter Semester - BDSA\PROG8420 - Programming for Big Data\Assignments\Final Assignment\data.xlsx')

# %% [markdown]
# ## Developing the Main Program
# #### We want the user to be able to input some key variables to find out how much money a player can make on tour

# %%
stat_name = []
stat_avg = []
var_num = []
predictions = []
# I supplied some average stats for the user, so they can have an idea of what an AVERAGE golfer could perform at
for c in range(0, len(X.columns)):
    stat_name.append(X.columns[c])
    stat_avg.append(X.iloc[:,c].mean())
    var_num.append(c)
    #print(X.columns[c],X.iloc[:,c].mean())
user_predictions = pd.DataFrame(columns = stat_name)
user_predictions.loc[len(user_predictions)] = stat_avg
#user_predictions.to_excel(r'C:\Users\foxnetadmin\Documents\Winter Semester - BDSA\PROG8420 - Programming for Big Data\Assignments\Final Assignment\user_predictions.xlsx')

# %%
# When the user is ready to make predictions they can access this excel spreadsheet.
newpred = pd.read_excel(r'user_predictions.xlsx')

# %%
newpred = newpred.drop('Unnamed: 0', axis = 1)
new_golf_pred = lm.predict(newpred)
# The first prediction is considered to be an averge golfer
# The second prediction is my "custom" golfer who is very strong in every aspect of the game, espcially putting and scoring.
new_golf_pred
# Out:
# array([1.79840891, 5.65784024])
